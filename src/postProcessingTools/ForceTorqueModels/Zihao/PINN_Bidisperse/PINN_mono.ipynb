# %%
# Initializations
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

import tensorflow as tf
from keras import metrics
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, Concatenate, Lambda, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split, KFold
tf.get_logger().setLevel('ERROR')
import warnings
warnings.filterwarnings('ignore')
import time
import gc

# %% [markdown]
# ## Tranformation to new scale

# %%
D = 0.001
mu = 1e-3
rho = 1000

Re = 150
phi = 4
u_c = (Re * mu) / (rho * D)

os.chdir("/home/zihao/Documents/PhD/Post-Processing/3D/Bidisperse")
dataset = pd.read_csv(f'Arman_PINN/dataset/Re{Re}_phi0{phi}',
                        header=None, delim_whitespace=True).values
for i in range(dataset.shape[0]): 
    dataset[i,-9] *= u_c
    dataset[i,-8] *= u_c
    dataset[i,-7] *= u_c
    V = np.linalg.norm(dataset[i,-9:-6])
    F = 0.5 * rho * (u_c**2) * ((np.pi * D**2) / 4) / (3 * np.pi * mu * D * V)
    T = 0.5 * rho * (u_c**2) * ((np.pi * D**2) / 4) * D / (mu * D**2 * V)
    dataset[i,-1] *= F
    dataset[i,-2] *= F
    dataset[i,-3] *= F
    dataset[i,-4] *= T
    dataset[i,-5] *= T
    dataset[i,-6] *= T
    dataset[i,-7] /= u_c
    dataset[i,-8] /= u_c
    dataset[i,-9] /= u_c
pd.DataFrame(dataset).to_csv(f'Arman_PINN/dataset/new_Re{Re}_phi0{phi}', header=None, index=None, sep=' ')

# %% [markdown]
# # Let's start the real game

# %% [markdown]
# ## $F_x$

# %%
# %reset -f array
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# free up memory from previous plots_________________
plt.close('all')
plt.clf()

coord = r'F_x' 

# load dataset _______________________________________
Re = 0.2
phi = 2

num_p_incl = 35
N_neurons = 30
epochs = 500
lr = 1.e-2
verbose = 0
batch_size = 128

# coord, title = 'F_x', r'$ Re = ' + f'{Re},' + r' \phi = ' + f'{phi} $'

os.chdir("/home/zihao/Documents/PhD/Post-Processing/3D/Bidisperse")
dataset = pd.read_csv(f'Arman_PINN/raw/new_Re02_phi0{phi}',
                        header=None, delim_whitespace=True).values

col_n = -3

X_in = dataset[:, :-6]
Y_in = dataset[:, [-3]]
Y_in -= Y_in.mean()

HUBER_ALPHA = Y_in.std()
print(HUBER_ALPHA)
    
kf = KFold(n_splits=5, shuffle=True)
train_scores = []
test_scores = []

X_test_plot = np.zeros((0, X_in.shape[1]))
Y_test_plot = np.zeros((0, 1))
Y_pred_test_plot = np.zeros((0, 1))

# from IPython.display import display, Math
# display(Math('$ \Delta ' + coord + ' $'))
# display(Math(title))

print('Input shape:', X_in.shape)
print(f'# of neighbors in the dataset = {int((X_in.shape[1] - 3) / 3)}')
print(f'# of neighbors used for training = {num_p_incl}')
print('________________________________________')

q = 0
Total_time_train = 0
Total_time_test  = 0
# Train-Test split for K-fold cross-validation _______________________________________
for train_index, test_index in kf.split(X_in):
    
    q += 1
    print(f'+++++++++++++++++++++++++Fold {q:1d}+++++++++++++++++++++++++')

    X_train_list = []
    X_test_list = []
    p_input_list = []
    p_out_list = []
    
    X_train, X_test = X_in[train_index], X_in[test_index]
    Y_train, Y_test = Y_in[train_index], Y_in[test_index]
            
    V_in_train = X_train[:, col_n:]
    V_in_test  = X_test[:, col_n:]
    
    # X_train_tmp = X_train
    # for p in range(0, 30):
    #     X_train_tmp[:,3*p+1] = -X_train_tmp[:,3*p+1]
    # X_train = np.vstack((X_train,X_train_tmp))
    # X_train_tmp = X_train
    # for p in range(0, 30):
    #     X_train_tmp[:,3*p+2] = -X_train_tmp[:,3*p+2]
    # X_train = np.vstack((X_train,X_train_tmp))
    # Y_train = np.vstack((Y_train,Y_train))
    # Y_train = np.vstack((Y_train,Y_train))
    # V_in_train_tmp = V_in_train
    # V_in_train_tmp[:,-2] = -V_in_train_tmp[:,-2]
    # V_in_train = np.vstack((V_in_train,V_in_train_tmp))
    # V_in_train_tmp = V_in_train
    # V_in_train_tmp[:,-1] = -V_in_train_tmp[:,-1]
    # V_in_train = np.vstack((V_in_train,V_in_train_tmp))
    
    # Training =======================================
    glorot = tf.keras.initializers.GlorotNormal()
        
    # Custom neural network _______________________________________
    p_shared_layer1 = Dense(N_neurons,
                            activation='elu',
                            kernel_initializer=glorot,
                            name='p_shared1')
    
    p_shared_layer2 = Dense(N_neurons,
                            activation='elu',
                            kernel_initializer=glorot,
                            name='p_shared2')
    
    p_shared_layer3 = Dense(N_neurons,
                            activation='elu',
                            kernel_initializer=glorot,
                            name='p_shared3')
    
    # p_shared_layer4 = Dense(N_neurons,
    #                         activation='elu',
    #                         kernel_initializer=glorot,
    #                         name='p_shared4')
    
#     p_shared_layer5 = Dense(N_neurons,
#                             activation='tanh',
#                             kernel_initializer=glorot,
#                             name='p_shared5')
    
    V_input = Input(shape=V_in_train.shape[1], name='V_in')
    
    V_layer = Dense(N_neurons,
                     activation='elu',
                     kernel_initializer=glorot,
                     name='V_layer1')(V_input)
    
    V_layer = Dense(N_neurons,
                     activation='elu',
                     kernel_initializer=glorot,
                     name='V_layer2')(V_layer)
    
    V_layer = Dense(N_neurons,
                     activation='elu',
                     kernel_initializer=glorot,
                     name='V_layer3')(V_layer)
    
    # V_layer = Dense(N_neurons,
    #                  activation='elu',
    #                  kernel_initializer=glorot,
    #                  name='V_layer4')(V_layer)
    
#     V_layer = Dense(N_neurons,
#                      activation='relu',
#                      kernel_initializer=glorot,
#                      name='V_layer5')(V_layer)
    
    def summation(p_tensor):
        '''
        Each individual neighbor contribution to drag is
        always directed along the x-direction.
        '''
        # Drag _______________________________________
        return tf.reduce_sum(p_tensor, axis=1, keepdims=True)
    #_______________________________________________________________________________

    for p in range(0, num_p_incl):
        X_train_list.append( X_train[:, 3*p:3*p+3])
        p_input_list.append( Input(shape=3, name=f'p_r{p}') )
        # p_out_list.append( tf.keras.layers.Multiply()([tf.keras.layers.Multiply()
        #                   ([p_shared_layer2(p_shared_layer1(p_input_list[p])),V_layer])
        #                                                ,R_input]) )
        # p_out_list.append( tf.keras.layers.Multiply()([p_shared_layer2(p_shared_layer1(p_input_list[p]))
        #                                                ,V_layer]) )
        p_out_list.append( tf.keras.layers.Multiply()([p_shared_layer3(p_shared_layer2(p_shared_layer1(p_input_list[p])))
                                                       ,V_layer]) )
        # p_out_list.append( tf.keras.layers.Multiply()([p_shared_layer4(p_shared_layer3(p_shared_layer2(p_shared_layer1(p_input_list[p]))))
        #                                                ,V_layer]) )

    concat = Concatenate()(
        [Lambda(summation, name=f'summation{j}')(p_out_list[j])\
        for j in range(num_p_incl)])
    
    # concat = tf.keras.layers.Multiply()([concat, V_layer])

    nonneg = tf.keras.constraints.NonNeg()

    # output_layer = Dense(1,
    #                     activation='elu',
    #                     name='out_x',
    #                     )(concat)
    
    output_layer = Dense(1,
                        activation='linear',
                        kernel_constraint=nonneg,
                        name='out_x',
                        use_bias=False
                        )(concat)
    
    # Neural net fitting _______________________________________
    
    def R2_val(y_true, y_pred):
        '''
        This function computes the R^2 for the callback function.
        '''
        SS_res = K.sum(K.square(y_true - y_pred)) 
        SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
        return 1 - SS_res / (SS_tot + K.epsilon())
    
    model = Model(inputs=p_input_list + [V_input], outputs=output_layer)

    # myoptimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    myoptimizer = tf.keras.optimizers.Nadam(learning_rate=lr)
    EarlyStop = EarlyStopping(monitor='val_loss', patience=60, min_delta=5e-5)
    LRDecay = ReduceLROnPlateau(monitor='val_loss', patience=20, factor=0.5, min_delta=1e-4)

    # model.compile(loss='mse', optimizer=myoptimizer, metrics=[metrics.mean_squared_error])
    # model.compile(loss='mean_absolute_error', optimizer=myoptimizer, metrics=[metrics.mean_squared_error])
    he = tf.keras.losses.Huber(delta=HUBER_ALPHA)
    model.compile(loss=he, optimizer=myoptimizer, metrics=R2_val)
    
    history_drag = model.fit(
                            X_train_list + [V_in_train],
                            Y_train,

                            validation_split=0.2,
                            shuffle=True,
                            epochs=epochs,
                            verbose=verbose,
                            batch_size=batch_size,
                            callbacks=[LRDecay,EarlyStop],
                            )
    
    start_time = time.perf_counter()
    Y_pred = model.predict(X_train_list + [V_in_train])
    end_time = time.perf_counter()
    print(f'CPU time: {end_time-start_time:.3f} for {Y_pred.shape[0]:8d} datapoints')
    Total_time_train += end_time-start_time
    
    print(f'Train R^2\t= {r2_score(Y_train, Y_pred):.3f}\n')
    train_scores.append(r2_score(Y_train, Y_pred))
    
    # Testing =======================================
    for p in range(0, num_p_incl):
        X_test_list.append( X_test[:, 3*p:3*p+3] )
        
    start_time = time.perf_counter()
    Y_pred_test = model.predict(X_test_list + [V_in_test])
    end_time = time.perf_counter()
    print(f'CPU time: {end_time-start_time:.3f} for {Y_pred_test.shape[0]:8d} datapoints')
    Total_time_test += end_time-start_time
    
    print(f'Test R^2\t= {r2_score(Y_test, Y_pred_test):.3f}\n')
    test_scores.append(r2_score(Y_test, Y_pred_test))

    # os.chdir("/home/zihao/Documents/PhD/Post-Processing/3D/Bidisperse/Datasets/Paper_3")
    # model.save(f'model_{coord}_Re{Re}_phi{phi}.h5')
    # os.chdir("../../")
    
    print(f'++++++++++++++++++++++++++++++++++++++++++++++++++++++++\n')
    
    if q != 5:
        del model
        K.clear_session()   
        gc.collect()
# os.chdir("/home/zihao/Documents/PhD/Post-Processing/3D/Bidisperse/Datasets/Paper_3")
# np.save(f'Re{Re}_phi{phi}_large_true_drag.npy',Y_large_test_plot)
# np.save(f'Re{Re}_phi{phi}_large_pred_drag.npy',Y_large_pred_test_plot)
# np.save(f'Re{Re}_phi{phi}_small_true_drag.npy',Y_small_test_plot)
# np.save(f'Re{Re}_phi{phi}_small_pred_drag.npy',Y_small_pred_test_plot)
# os.chdir("../../")

Average_train_scores = np.mean(train_scores)
Average_test_scores = np.mean(test_scores)

print('========================================\nOverall performance:')
print(f'<Average Train R^2> = {Average_train_scores:.3f}')
print(f'<Average Test R^2> = {Average_test_scores:.3f}')
print(f'<Average Train time> = {(Total_time_train/5):.3f}')
print(f'<Average Test time> = {(Total_time_test/5):.3f}')

print(f'\nTotal number of model parameters: {model.count_params()}\n')
# os.chdir("/home/zihao/Documents/PhD/Post-Processing/3D/Bidisperse/Datasets/Paper_3")
# model.save(f'model_{coord}_Re{Re}_phi{phi}.h5')
# os.chdir("../../")
model.summary()
del model
K.clear_session()   
gc.collect()
# Out:
# 0.8136954406728841
# Input shape: (3055, 300)
# # of neighbors in the dataset = 99
# # of neighbors used for training = 35
# ________________________________________
# +++++++++++++++++++++++++Fold 1+++++++++++++++++++++++++
# 77/77 [==============================] - 1s 7ms/step
# CPU time: 52.351 for     2444 datapoints
# Train R^2	= 0.834
#
# 20/20 [==============================] - 0s 8ms/step
# CPU time: 0.504 for      611 datapoints
# Test R^2	= 0.815
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++Fold 2+++++++++++++++++++++++++
# 77/77 [==============================] - 1s 5ms/step
# CPU time: 18.297 for     2444 datapoints
# Train R^2	= 0.839
#
# 20/20 [==============================] - 0s 6ms/step
# CPU time: 0.378 for      611 datapoints
# Test R^2	= 0.768
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++Fold 3+++++++++++++++++++++++++
# 77/77 [==============================] - 1s 7ms/step
# CPU time: 1.078 for     2444 datapoints
# Train R^2	= 0.846
#
# 20/20 [==============================] - 0s 5ms/step
# CPU time: 0.305 for      611 datapoints
# Test R^2	= 0.778
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++Fold 4+++++++++++++++++++++++++
# 77/77 [==============================] - 1s 5ms/step
# CPU time: 54.331 for     2444 datapoints
# Train R^2	= 0.834
#
# 20/20 [==============================] - 0s 6ms/step
# CPU time: 0.232 for      611 datapoints
# Test R^2	= 0.774
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++Fold 5+++++++++++++++++++++++++
# 77/77 [==============================] - 1s 6ms/step
# CPU time: 54.415 for     2444 datapoints
# Train R^2	= 0.846
#
# 20/20 [==============================] - 0s 8ms/step
# CPU time: 0.422 for      611 datapoints
# Test R^2	= 0.795
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# ========================================
# Overall performance:
# <Average Train R^2> = 0.840
# <Average Test R^2> = 0.786
# <Average Train time> = 36.094
# <Average Test time> = 0.368
#
# Total number of model parameters: 3995
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  p_r0 (InputLayer)              [(None, 3)]          0           []
#
#  V_in (InputLayer)              [(None, 3)]          0           []
#
#  p_r1 (InputLayer)              [(None, 3)]          0           []
#
#  p_r2 (InputLayer)              [(None, 3)]          0           []
#
#  p_r3 (InputLayer)              [(None, 3)]          0           []
#
#  p_r4 (InputLayer)              [(None, 3)]          0           []
#
#  p_r5 (InputLayer)              [(None, 3)]          0           []
#
#  p_r6 (InputLayer)              [(None, 3)]          0           []
#
#  p_r7 (InputLayer)              [(None, 3)]          0           []
#
#  p_r8 (InputLayer)              [(None, 3)]          0           []
#
#  p_r9 (InputLayer)              [(None, 3)]          0           []
#
#  p_r10 (InputLayer)             [(None, 3)]          0           []
#
#  p_r11 (InputLayer)             [(None, 3)]          0           []
#
#  p_r12 (InputLayer)             [(None, 3)]          0           []
#
#  p_r13 (InputLayer)             [(None, 3)]          0           []
#
#  p_r14 (InputLayer)             [(None, 3)]          0           []
#
#  p_r15 (InputLayer)             [(None, 3)]          0           []
#
#  p_r16 (InputLayer)             [(None, 3)]          0           []
#
#  p_r17 (InputLayer)             [(None, 3)]          0           []
#
#  p_r18 (InputLayer)             [(None, 3)]          0           []
#
#  p_r19 (InputLayer)             [(None, 3)]          0           []
#
#  p_r20 (InputLayer)             [(None, 3)]          0           []
#
#  p_r21 (InputLayer)             [(None, 3)]          0           []
#
#  p_r22 (InputLayer)             [(None, 3)]          0           []
#
#  p_r23 (InputLayer)             [(None, 3)]          0           []
#
#  p_r24 (InputLayer)             [(None, 3)]          0           []
#
#  p_r25 (InputLayer)             [(None, 3)]          0           []
#
#  p_r26 (InputLayer)             [(None, 3)]          0           []
#
#  p_r27 (InputLayer)             [(None, 3)]          0           []
#
#  p_r28 (InputLayer)             [(None, 3)]          0           []
#
#  p_r29 (InputLayer)             [(None, 3)]          0           []
#
#  p_r30 (InputLayer)             [(None, 3)]          0           []
#
#  p_r31 (InputLayer)             [(None, 3)]          0           []
#
#  p_r32 (InputLayer)             [(None, 3)]          0           []
#
#  p_r33 (InputLayer)             [(None, 3)]          0           []
#
#  p_r34 (InputLayer)             [(None, 3)]          0           []
#
#  p_shared1 (Dense)              (None, 30)           120         ['p_r0[0][0]',
#                                                                   'p_r1[0][0]',
#                                                                   'p_r2[0][0]',
#                                                                   'p_r3[0][0]',
#                                                                   'p_r4[0][0]',
#                                                                   'p_r5[0][0]',
#                                                                   'p_r6[0][0]',
#                                                                   'p_r7[0][0]',
#                                                                   'p_r8[0][0]',
#                                                                   'p_r9[0][0]',
#                                                                   'p_r10[0][0]',
#                                                                   'p_r11[0][0]',
#                                                                   'p_r12[0][0]',
#                                                                   'p_r13[0][0]',
#                                                                   'p_r14[0][0]',
#                                                                   'p_r15[0][0]',
#                                                                   'p_r16[0][0]',
#                                                                   'p_r17[0][0]',
#                                                                   'p_r18[0][0]',
#                                                                   'p_r19[0][0]',
#                                                                   'p_r20[0][0]',
#                                                                   'p_r21[0][0]',
#                                                                   'p_r22[0][0]',
#                                                                   'p_r23[0][0]',
#                                                                   'p_r24[0][0]',
#                                                                   'p_r25[0][0]',
#                                                                   'p_r26[0][0]',
#                                                                   'p_r27[0][0]',
#                                                                   'p_r28[0][0]',
#                                                                   'p_r29[0][0]',
#                                                                   'p_r30[0][0]',
#                                                                   'p_r31[0][0]',
#                                                                   'p_r32[0][0]',
#                                                                   'p_r33[0][0]',
#                                                                   'p_r34[0][0]']
#
#  V_layer1 (Dense)               (None, 30)           120         ['V_in[0][0]']
#
#  p_shared2 (Dense)              (None, 30)           930         ['p_shared1[0][0]',
#                                                                   'p_shared1[1][0]',
#                                                                   'p_shared1[2][0]',
#                                                                   'p_shared1[3][0]',
#                                                                   'p_shared1[4][0]',
#                                                                   'p_shared1[5][0]',
#                                                                   'p_shared1[6][0]',
#                                                                   'p_shared1[7][0]',
#                                                                   'p_shared1[8][0]',
#                                                                   'p_shared1[9][0]',
#                                                                   'p_shared1[10][0]',
#                                                                   'p_shared1[11][0]',
#                                                                   'p_shared1[12][0]',
#                                                                   'p_shared1[13][0]',
#                                                                   'p_shared1[14][0]',
#                                                                   'p_shared1[15][0]',
#                                                                   'p_shared1[16][0]',
#                                                                   'p_shared1[17][0]',
#                                                                   'p_shared1[18][0]',
#                                                                   'p_shared1[19][0]',
#                                                                   'p_shared1[20][0]',
#                                                                   'p_shared1[21][0]',
#                                                                   'p_shared1[22][0]',
#                                                                   'p_shared1[23][0]',
#                                                                   'p_shared1[24][0]',
#                                                                   'p_shared1[25][0]',
#                                                                   'p_shared1[26][0]',
#                                                                   'p_shared1[27][0]',
#                                                                   'p_shared1[28][0]',
#                                                                   'p_shared1[29][0]',
#                                                                   'p_shared1[30][0]',
#                                                                   'p_shared1[31][0]',
#                                                                   'p_shared1[32][0]',
#                                                                   'p_shared1[33][0]',
#                                                                   'p_shared1[34][0]']
#
#  V_layer2 (Dense)               (None, 30)           930         ['V_layer1[0][0]']
#
#  p_shared3 (Dense)              (None, 30)           930         ['p_shared2[0][0]',
#                                                                   'p_shared2[1][0]',
#                                                                   'p_shared2[2][0]',
#                                                                   'p_shared2[3][0]',
#                                                                   'p_shared2[4][0]',
#                                                                   'p_shared2[5][0]',
#                                                                   'p_shared2[6][0]',
#                                                                   'p_shared2[7][0]',
#                                                                   'p_shared2[8][0]',
#                                                                   'p_shared2[9][0]',
#                                                                   'p_shared2[10][0]',
#                                                                   'p_shared2[11][0]',
#                                                                   'p_shared2[12][0]',
#                                                                   'p_shared2[13][0]',
#                                                                   'p_shared2[14][0]',
#                                                                   'p_shared2[15][0]',
#                                                                   'p_shared2[16][0]',
#                                                                   'p_shared2[17][0]',
#                                                                   'p_shared2[18][0]',
#                                                                   'p_shared2[19][0]',
#                                                                   'p_shared2[20][0]',
#                                                                   'p_shared2[21][0]',
#                                                                   'p_shared2[22][0]',
#                                                                   'p_shared2[23][0]',
#                                                                   'p_shared2[24][0]',
#                                                                   'p_shared2[25][0]',
#                                                                   'p_shared2[26][0]',
#                                                                   'p_shared2[27][0]',
#                                                                   'p_shared2[28][0]',
#                                                                   'p_shared2[29][0]',
#                                                                   'p_shared2[30][0]',
#                                                                   'p_shared2[31][0]',
#                                                                   'p_shared2[32][0]',
#                                                                   'p_shared2[33][0]',
#                                                                   'p_shared2[34][0]']
#
#  V_layer3 (Dense)               (None, 30)           930         ['V_layer2[0][0]']
#
#  multiply (Multiply)            (None, 30)           0           ['p_shared3[0][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_1 (Multiply)          (None, 30)           0           ['p_shared3[1][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_2 (Multiply)          (None, 30)           0           ['p_shared3[2][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_3 (Multiply)          (None, 30)           0           ['p_shared3[3][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_4 (Multiply)          (None, 30)           0           ['p_shared3[4][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_5 (Multiply)          (None, 30)           0           ['p_shared3[5][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_6 (Multiply)          (None, 30)           0           ['p_shared3[6][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_7 (Multiply)          (None, 30)           0           ['p_shared3[7][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_8 (Multiply)          (None, 30)           0           ['p_shared3[8][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_9 (Multiply)          (None, 30)           0           ['p_shared3[9][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_10 (Multiply)         (None, 30)           0           ['p_shared3[10][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_11 (Multiply)         (None, 30)           0           ['p_shared3[11][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_12 (Multiply)         (None, 30)           0           ['p_shared3[12][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_13 (Multiply)         (None, 30)           0           ['p_shared3[13][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_14 (Multiply)         (None, 30)           0           ['p_shared3[14][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_15 (Multiply)         (None, 30)           0           ['p_shared3[15][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_16 (Multiply)         (None, 30)           0           ['p_shared3[16][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_17 (Multiply)         (None, 30)           0           ['p_shared3[17][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_18 (Multiply)         (None, 30)           0           ['p_shared3[18][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_19 (Multiply)         (None, 30)           0           ['p_shared3[19][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_20 (Multiply)         (None, 30)           0           ['p_shared3[20][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_21 (Multiply)         (None, 30)           0           ['p_shared3[21][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_22 (Multiply)         (None, 30)           0           ['p_shared3[22][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_23 (Multiply)         (None, 30)           0           ['p_shared3[23][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_24 (Multiply)         (None, 30)           0           ['p_shared3[24][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_25 (Multiply)         (None, 30)           0           ['p_shared3[25][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_26 (Multiply)         (None, 30)           0           ['p_shared3[26][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_27 (Multiply)         (None, 30)           0           ['p_shared3[27][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_28 (Multiply)         (None, 30)           0           ['p_shared3[28][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_29 (Multiply)         (None, 30)           0           ['p_shared3[29][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_30 (Multiply)         (None, 30)           0           ['p_shared3[30][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_31 (Multiply)         (None, 30)           0           ['p_shared3[31][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_32 (Multiply)         (None, 30)           0           ['p_shared3[32][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_33 (Multiply)         (None, 30)           0           ['p_shared3[33][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_34 (Multiply)         (None, 30)           0           ['p_shared3[34][0]',
#                                                                   'V_layer3[0][0]']
#
#  summation0 (Lambda)            (None, 1)            0           ['multiply[0][0]']
#
#  summation1 (Lambda)            (None, 1)            0           ['multiply_1[0][0]']
#
#  summation2 (Lambda)            (None, 1)            0           ['multiply_2[0][0]']
#
#  summation3 (Lambda)            (None, 1)            0           ['multiply_3[0][0]']
#
#  summation4 (Lambda)            (None, 1)            0           ['multiply_4[0][0]']
#
#  summation5 (Lambda)            (None, 1)            0           ['multiply_5[0][0]']
#
#  summation6 (Lambda)            (None, 1)            0           ['multiply_6[0][0]']
#
#  summation7 (Lambda)            (None, 1)            0           ['multiply_7[0][0]']
#
#  summation8 (Lambda)            (None, 1)            0           ['multiply_8[0][0]']
#
#  summation9 (Lambda)            (None, 1)            0           ['multiply_9[0][0]']
#
#  summation10 (Lambda)           (None, 1)            0           ['multiply_10[0][0]']
#
#  summation11 (Lambda)           (None, 1)            0           ['multiply_11[0][0]']
#
#  summation12 (Lambda)           (None, 1)            0           ['multiply_12[0][0]']
#
#  summation13 (Lambda)           (None, 1)            0           ['multiply_13[0][0]']
#
#  summation14 (Lambda)           (None, 1)            0           ['multiply_14[0][0]']
#
#  summation15 (Lambda)           (None, 1)            0           ['multiply_15[0][0]']
#
#  summation16 (Lambda)           (None, 1)            0           ['multiply_16[0][0]']
#
#  summation17 (Lambda)           (None, 1)            0           ['multiply_17[0][0]']
#
#  summation18 (Lambda)           (None, 1)            0           ['multiply_18[0][0]']
#
#  summation19 (Lambda)           (None, 1)            0           ['multiply_19[0][0]']
#
#  summation20 (Lambda)           (None, 1)            0           ['multiply_20[0][0]']
#
#  summation21 (Lambda)           (None, 1)            0           ['multiply_21[0][0]']
#
#  summation22 (Lambda)           (None, 1)            0           ['multiply_22[0][0]']
#
#  summation23 (Lambda)           (None, 1)            0           ['multiply_23[0][0]']
#
#  summation24 (Lambda)           (None, 1)            0           ['multiply_24[0][0]']
#
#  summation25 (Lambda)           (None, 1)            0           ['multiply_25[0][0]']
#
#  summation26 (Lambda)           (None, 1)            0           ['multiply_26[0][0]']
#
#  summation27 (Lambda)           (None, 1)            0           ['multiply_27[0][0]']
#
#  summation28 (Lambda)           (None, 1)            0           ['multiply_28[0][0]']
#
#  summation29 (Lambda)           (None, 1)            0           ['multiply_29[0][0]']
#
#  summation30 (Lambda)           (None, 1)            0           ['multiply_30[0][0]']
#
#  summation31 (Lambda)           (None, 1)            0           ['multiply_31[0][0]']
#
#  summation32 (Lambda)           (None, 1)            0           ['multiply_32[0][0]']
#
#  summation33 (Lambda)           (None, 1)            0           ['multiply_33[0][0]']
#
#  summation34 (Lambda)           (None, 1)            0           ['multiply_34[0][0]']
#
#  concatenate (Concatenate)      (None, 35)           0           ['summation0[0][0]',
#                                                                   'summation1[0][0]',
#                                                                   'summation2[0][0]',
#                                                                   'summation3[0][0]',
#                                                                   'summation4[0][0]',
#                                                                   'summation5[0][0]',
#                                                                   'summation6[0][0]',
#                                                                   'summation7[0][0]',
#                                                                   'summation8[0][0]',
#                                                                   'summation9[0][0]',
#                                                                   'summation10[0][0]',
#                                                                   'summation11[0][0]',
#                                                                   'summation12[0][0]',
#                                                                   'summation13[0][0]',
#                                                                   'summation14[0][0]',
#                                                                   'summation15[0][0]',
#                                                                   'summation16[0][0]',
#                                                                   'summation17[0][0]',
#                                                                   'summation18[0][0]',
#                                                                   'summation19[0][0]',
#                                                                   'summation20[0][0]',
#                                                                   'summation21[0][0]',
#                                                                   'summation22[0][0]',
#                                                                   'summation23[0][0]',
#                                                                   'summation24[0][0]',
#                                                                   'summation25[0][0]',
#                                                                   'summation26[0][0]',
#                                                                   'summation27[0][0]',
#                                                                   'summation28[0][0]',
#                                                                   'summation29[0][0]',
#                                                                   'summation30[0][0]',
#                                                                   'summation31[0][0]',
#                                                                   'summation32[0][0]',
#                                                                   'summation33[0][0]',
#                                                                   'summation34[0][0]']
#
#  out_x (Dense)                  (None, 1)            35          ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 3,995
# Trainable params: 3,995
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 17820

# %% [markdown]
# ## $F_L$

# %%
# %reset -f array
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# free up memory from previous plots_________________
plt.close('all')
plt.clf()

coord = r'F_L' 

# load dataset _______________________________________
Re = 150
phi = 4

num_p_incl = 35
N_neurons = 30
epochs = 500
lr = 1.e-2
verbose = 0
batch_size = 128

# coord, title = 'F_x', r'$ Re = ' + f'{Re},' + r' \phi = ' + f'{phi} $'

os.chdir("/home/zihao/Documents/PhD/Post-Processing/3D/Bidisperse")
dataset = pd.read_csv(f'Arman_PINN/raw/new_Re{Re}_phi0{phi}',
                        header=None, delim_whitespace=True).values

col_n = -3

X_in = dataset[:, :-6]
if coord == 'F_L':
    Y_in = dataset[:, -2:]
if coord == 'T_L':
    Y_in = dataset[:, -5:-3]
Y_in -= Y_in.mean(axis=0)

HUBER_ALPHA = max(Y_in[:,0].std(),Y_in[:,1].std())
print(HUBER_ALPHA)
    
kf = KFold(n_splits=5, shuffle=True)
train_scores = []
test_scores = []

X_test_plot = np.zeros((0, X_in.shape[1]))
Y_test_plot = np.zeros((0, Y_in.shape[1]))
Y_pred_test_plot = np.zeros((0, Y_in.shape[1]))

# from IPython.display import display, Math
# display(Math('$ \Delta ' + coord + ' $'))
# display(Math(title))

print('Input shape:', X_in.shape)
print(f'# of neighbors in the dataset = {int((X_in.shape[1] - 3) / 3)}')
print(f'# of neighbors used for training = {num_p_incl}')
print('________________________________________')

q = 0
Total_time_train = 0
Total_time_test  = 0
# Train-Test split for K-fold cross-validation _______________________________________
for train_index, test_index in kf.split(X_in):
    
    q += 1
    print(f'+++++++++++++++++++++++++Fold {q:1d}+++++++++++++++++++++++++')

    X_train_list = []
    X_test_list = []
    p_input_list = []
    p_out_list = []
    
    X_train, X_test = X_in[train_index], X_in[test_index]
    Y_train, Y_test = Y_in[train_index], Y_in[test_index]
            
    V_in_train = X_train[:, col_n:]
    V_in_test  = X_test[:, col_n:]
    
    # X_train_tmp = X_train
    # for p in range(0, 30):
    #     X_train_tmp[:,3*p+1] = -X_train_tmp[:,3*p+1]
    # X_train = np.vstack((X_train,X_train_tmp))
    # X_train_tmp = X_train
    # for p in range(0, 30):
    #     X_train_tmp[:,3*p+2] = -X_train_tmp[:,3*p+2]
    # X_train = np.vstack((X_train,X_train_tmp))
    # Y_train = np.vstack((Y_train,Y_train))
    # Y_train = np.vstack((Y_train,Y_train))
    # V_in_train_tmp = V_in_train
    # V_in_train_tmp[:,-2] = -V_in_train_tmp[:,-2]
    # V_in_train = np.vstack((V_in_train,V_in_train_tmp))
    # V_in_train_tmp = V_in_train
    # V_in_train_tmp[:,-1] = -V_in_train_tmp[:,-1]
    # V_in_train = np.vstack((V_in_train,V_in_train_tmp))
    
    # Training =======================================
    glorot = tf.keras.initializers.GlorotNormal()
        
    # Custom neural network _______________________________________
    p_shared_layer1 = Dense(N_neurons,
                            activation='elu',
                            kernel_initializer=glorot,
                            name='p_shared1')
    
    p_shared_layer2 = Dense(N_neurons,
                            activation='elu',
                            kernel_initializer=glorot,
                            name='p_shared2')
    
    p_shared_layer3 = Dense(N_neurons,
                            activation='elu',
                            kernel_initializer=glorot,
                            name='p_shared3')
    
    # p_shared_layer4 = Dense(N_neurons,
    #                         activation='elu',
    #                         kernel_initializer=glorot,
    #                         name='p_shared4')
    
#     p_shared_layer5 = Dense(N_neurons,
#                             activation='tanh',
#                             kernel_initializer=glorot,
#                             name='p_shared5')
    
    V_input = Input(shape=V_in_train.shape[1], name='V_in')
    
    V_layer = Dense(N_neurons,
                     activation='elu',
                     kernel_initializer=glorot,
                     name='V_layer1')(V_input)
    
    V_layer = Dense(N_neurons,
                     activation='elu',
                     kernel_initializer=glorot,
                     name='V_layer2')(V_layer)
    
    V_layer = Dense(N_neurons,
                     activation='elu',
                     kernel_initializer=glorot,
                     name='V_layer3')(V_layer)
    
    # V_layer = Dense(N_neurons,
    #                  activation='elu',
    #                  kernel_initializer=glorot,
    #                  name='V_layer4')(V_layer)
    
#     V_layer = Dense(N_neurons,
#                      activation='relu',
#                      kernel_initializer=glorot,
#                      name='V_layer5')(V_layer)
    
    def project_y(inputs):
        pos_vec = inputs[0]
        p_tensor = inputs[1]

        e_x = tf.constant(np.array([1, 0, 0]), shape=(1, 3), dtype=tf.float32)
        e_y = tf.constant(np.array([0, 1, 0]), shape=(1, 3), dtype=tf.float32)
        e_z = tf.constant(np.array([0, 0, 1]), shape=(1, 3), dtype=tf.float32)

        e_x = tf.broadcast_to(e_x, shape=(tf.shape(p_tensor)[0], 3))
        e_y = tf.broadcast_to(e_y, shape=(tf.shape(p_tensor)[0], 3))
        e_z = tf.broadcast_to(e_z, shape=(tf.shape(p_tensor)[0], 3))

        e_r = pos_vec / tf.linalg.norm(pos_vec, axis=1, keepdims=True)

        # Lift _______________________________________
        if coord == 'F_L':
            e_ctrb = tf.linalg.cross(tf.linalg.cross(e_x, e_r), e_x)

        # Torque _______________________________________
        if coord == 'T_L':
            e_ctrb = tf.linalg.cross(e_x, e_r)

        e_ctrb /= tf.linalg.norm(e_ctrb, axis=1, keepdims=True)
        ctrb = tf.reduce_sum(p_tensor, axis=1, keepdims=True) * e_ctrb

        return tf.reduce_sum( tf.multiply( ctrb, e_y ), axis=1, keepdims=True )
    #_______________________________________________________________________________

    def project_z(inputs):
        pos_vec = inputs[0]
        p_tensor = inputs[1]

        e_x = tf.constant(np.array([1, 0, 0]), shape=(1, 3), dtype=tf.float32)
        e_y = tf.constant(np.array([0, 1, 0]), shape=(1, 3), dtype=tf.float32)
        e_z = tf.constant(np.array([0, 0, 1]), shape=(1, 3), dtype=tf.float32)

        e_x = tf.broadcast_to(e_x, shape=(tf.shape(p_tensor)[0], 3))
        e_y = tf.broadcast_to(e_y, shape=(tf.shape(p_tensor)[0], 3))
        e_z = tf.broadcast_to(e_z, shape=(tf.shape(p_tensor)[0], 3))
        
        e_r = pos_vec / tf.linalg.norm(pos_vec, axis=1, keepdims=True)

        # Lift _______________________________________
        if coord == 'F_L':
            e_ctrb = tf.linalg.cross(tf.linalg.cross(e_x, e_r), e_x)

        # Torque _______________________________________
        if coord == 'T_L':
            e_ctrb = tf.linalg.cross(e_x, e_r)

        e_ctrb /= tf.linalg.norm(e_ctrb, axis=1, keepdims=True)
        ctrb = tf.reduce_sum(p_tensor, axis=1, keepdims=True) * e_ctrb

        return tf.reduce_sum( tf.multiply( ctrb, e_z ), axis=1, keepdims=True )
    #_______________________________________________________________________________

    for p in range(0, num_p_incl):
        X_train_list.append( X_train[:, 3*p:3*p+3])
        p_input_list.append( Input(shape=3, name=f'p_r{p}') )
        # p_out_list.append( tf.keras.layers.Multiply()([tf.keras.layers.Multiply()
        #                   ([p_shared_layer2(p_shared_layer1(p_input_list[p])),V_layer])
        #                                                ,R_input]) )
        # p_out_list.append( tf.keras.layers.Multiply()([p_shared_layer2(p_shared_layer1(p_input_list[p]))
        #                                                ,V_layer]) )
        p_out_list.append( tf.keras.layers.Multiply()([p_shared_layer3(p_shared_layer2(p_shared_layer1(p_input_list[p])))
                                                       ,V_layer]) )
        # p_out_list.append( tf.keras.layers.Multiply()([p_shared_layer4(p_shared_layer3(p_shared_layer2(p_shared_layer1(p_input_list[p]))))
        #                                                ,V_layer]) )

    ctrb_y = Concatenate()(
        [Lambda(project_y, name=f'proj_y{j}')([p_input_list[j], p_out_list[j]])\
        for j in range(num_p_incl)])
    ctrb_z = Concatenate()(
        [Lambda(project_z, name=f'proj_z{j}')([p_input_list[j], p_out_list[j]])\
        for j in range(num_p_incl)])

    nonneg = tf.keras.constraints.NonNeg()

    out_y = Dense(1, activation='linear',
                #   kernel_initializer=tf.keras.initializers.zeros(),
                  kernel_constraint=nonneg,
                name='out_y', use_bias=False)(ctrb_y)
    out_z = Dense(1, activation='linear',
                #   kernel_initializer=tf.keras.initializers.zeros(),
                  kernel_constraint=nonneg,
                name='out_z', use_bias=False)(ctrb_z)
    
    out = Concatenate(name='out_concat_layer')([out_y, out_z])
    
    # Neural net fitting _______________________________________
    
    def R2_val(y_true, y_pred):
        '''
        This function computes the R^2 for the callback function.
        '''
        SS_res = K.sum(K.square(y_true - y_pred)) 
        SS_tot = K.sum(K.square(y_true - K.mean(y_true,axis=0))) 
        return 1 - SS_res / (SS_tot + K.epsilon())
    
    model = Model(inputs=p_input_list + [V_input], outputs=out)

    # myoptimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    myoptimizer = tf.keras.optimizers.Nadam(learning_rate=lr)
    EarlyStop = EarlyStopping(monitor='val_loss', patience=60, min_delta=5e-5)
    LRDecay = ReduceLROnPlateau(monitor='val_loss', patience=20, factor=0.5, min_delta=1e-4)

    # model.compile(loss='mse', optimizer=myoptimizer, metrics=[metrics.mean_squared_error])
    # model.compile(loss='mean_absolute_error', optimizer=myoptimizer, metrics=[metrics.mean_squared_error])
    he = tf.keras.losses.Huber(delta=HUBER_ALPHA)
    model.compile(loss=he, optimizer=myoptimizer, metrics=R2_val)
    
    history_drag = model.fit(
                            X_train_list + [V_in_train],
                            Y_train,

                            validation_split=0.2,
                            shuffle=True,
                            epochs=epochs,
                            verbose=verbose,
                            batch_size=batch_size,
                            callbacks=[LRDecay,EarlyStop],
                            )
    
    start_time = time.perf_counter()
    Y_pred = model.predict(X_train_list + [V_in_train])
    end_time = time.perf_counter()
    print(f'CPU time: {end_time-start_time:.3f} for {Y_pred.shape[0]:8d} datapoints')
    Total_time_train += end_time-start_time
    
    print(f'Train R^2\t= {r2_score(Y_train, Y_pred):.3f}\n')
    train_scores.append(r2_score(Y_train, Y_pred))
    
    # Testing =======================================
    for p in range(0, num_p_incl):
        X_test_list.append( X_test[:, 3*p:3*p+3] )
        
    start_time = time.perf_counter()
    Y_pred_test = model.predict(X_test_list + [V_in_test])
    end_time = time.perf_counter()
    print(f'CPU time: {end_time-start_time:.3f} for {Y_pred_test.shape[0]:8d} datapoints')
    Total_time_test += end_time-start_time
    
    print(f'Test R^2\t= {r2_score(Y_test, Y_pred_test):.3f}\n')
    test_scores.append(r2_score(Y_test, Y_pred_test))

    # os.chdir("/home/zihao/Documents/PhD/Post-Processing/3D/Bidisperse/Datasets/Paper_3")
    # model.save(f'model_{coord}_Re{Re}_phi{phi}.h5')
    # os.chdir("../../")
    
    print(f'++++++++++++++++++++++++++++++++++++++++++++++++++++++++\n')
    
    if q != 5:
        del model
        K.clear_session()   
        gc.collect()
# os.chdir("/home/zihao/Documents/PhD/Post-Processing/3D/Bidisperse/Datasets/Paper_3")
# np.save(f'Re{Re}_phi{phi}_large_true_drag.npy',Y_large_test_plot)
# np.save(f'Re{Re}_phi{phi}_large_pred_drag.npy',Y_large_pred_test_plot)
# np.save(f'Re{Re}_phi{phi}_small_true_drag.npy',Y_small_test_plot)
# np.save(f'Re{Re}_phi{phi}_small_pred_drag.npy',Y_small_pred_test_plot)
# os.chdir("../../")

Average_train_scores = np.mean(train_scores)
Average_test_scores = np.mean(test_scores)

print('========================================\nOverall performance:')
print(f'<Average Train R^2> = {Average_train_scores:.3f}')
print(f'<Average Test R^2> = {Average_test_scores:.3f}')
print(f'<Average Train time> = {(Total_time_train/5):.3f}')
print(f'<Average Test time> = {(Total_time_test/5):.3f}')

print(f'\nTotal number of model parameters: {model.count_params()}\n')
# os.chdir("/home/zihao/Documents/PhD/Post-Processing/3D/Bidisperse/Datasets/Paper_3")
# model.save(f'model_{coord}_Re{Re}_phi{phi}.h5')
# os.chdir("../../")
model.summary()
del model
K.clear_session()   
gc.collect()
# Out:
# 7.213352694286313
# Input shape: (2578, 300)
# # of neighbors in the dataset = 99
# # of neighbors used for training = 35
# ________________________________________
# +++++++++++++++++++++++++Fold 1+++++++++++++++++++++++++
# 65/65 [==============================] - 4s 10ms/step
# CPU time: 40.800 for     2062 datapoints
# Train R^2	= 0.556
#
# 17/17 [==============================] - 0s 5ms/step
# CPU time: 0.312 for      516 datapoints
# Test R^2	= 0.492
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++Fold 2+++++++++++++++++++++++++
# 65/65 [==============================] - 3s 4ms/step
# CPU time: 3.049 for     2062 datapoints
# Train R^2	= 0.594
#
# 17/17 [==============================] - 0s 5ms/step
# CPU time: 0.282 for      516 datapoints
# Test R^2	= 0.498
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++Fold 3+++++++++++++++++++++++++
# 65/65 [==============================] - 3s 9ms/step
# CPU time: 6.428 for     2062 datapoints
# Train R^2	= 0.630
#
# 17/17 [==============================] - 0s 8ms/step
# CPU time: 0.331 for      516 datapoints
# Test R^2	= 0.546
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++Fold 4+++++++++++++++++++++++++
# 65/65 [==============================] - 3s 7ms/step
# CPU time: 3.164 for     2063 datapoints
# Train R^2	= 0.646
#
# 17/17 [==============================] - 0s 11ms/step
# CPU time: 0.524 for      515 datapoints
# Test R^2	= 0.513
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++Fold 5+++++++++++++++++++++++++
# 65/65 [==============================] - 3s 6ms/step
# CPU time: 30.921 for     2063 datapoints
# Train R^2	= 0.563
#
# 17/17 [==============================] - 0s 5ms/step
# CPU time: 0.223 for      515 datapoints
# Test R^2	= 0.484
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# ========================================
# Overall performance:
# <Average Train R^2> = 0.598
# <Average Test R^2> = 0.507
# <Average Train time> = 16.872
# <Average Test time> = 0.335
#
# Total number of model parameters: 4030
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  p_r0 (InputLayer)              [(None, 3)]          0           []
#
#  V_in (InputLayer)              [(None, 3)]          0           []
#
#  p_r1 (InputLayer)              [(None, 3)]          0           []
#
#  p_r2 (InputLayer)              [(None, 3)]          0           []
#
#  p_r3 (InputLayer)              [(None, 3)]          0           []
#
#  p_r4 (InputLayer)              [(None, 3)]          0           []
#
#  p_r5 (InputLayer)              [(None, 3)]          0           []
#
#  p_r6 (InputLayer)              [(None, 3)]          0           []
#
#  p_r7 (InputLayer)              [(None, 3)]          0           []
#
#  p_r8 (InputLayer)              [(None, 3)]          0           []
#
#  p_r9 (InputLayer)              [(None, 3)]          0           []
#
#  p_r10 (InputLayer)             [(None, 3)]          0           []
#
#  p_r11 (InputLayer)             [(None, 3)]          0           []
#
#  p_r12 (InputLayer)             [(None, 3)]          0           []
#
#  p_r13 (InputLayer)             [(None, 3)]          0           []
#
#  p_r14 (InputLayer)             [(None, 3)]          0           []
#
#  p_r15 (InputLayer)             [(None, 3)]          0           []
#
#  p_r16 (InputLayer)             [(None, 3)]          0           []
#
#  p_r17 (InputLayer)             [(None, 3)]          0           []
#
#  p_r18 (InputLayer)             [(None, 3)]          0           []
#
#  p_r19 (InputLayer)             [(None, 3)]          0           []
#
#  p_r20 (InputLayer)             [(None, 3)]          0           []
#
#  p_r21 (InputLayer)             [(None, 3)]          0           []
#
#  p_r22 (InputLayer)             [(None, 3)]          0           []
#
#  p_r23 (InputLayer)             [(None, 3)]          0           []
#
#  p_r24 (InputLayer)             [(None, 3)]          0           []
#
#  p_r25 (InputLayer)             [(None, 3)]          0           []
#
#  p_r26 (InputLayer)             [(None, 3)]          0           []
#
#  p_r27 (InputLayer)             [(None, 3)]          0           []
#
#  p_r28 (InputLayer)             [(None, 3)]          0           []
#
#  p_r29 (InputLayer)             [(None, 3)]          0           []
#
#  p_r30 (InputLayer)             [(None, 3)]          0           []
#
#  p_r31 (InputLayer)             [(None, 3)]          0           []
#
#  p_r32 (InputLayer)             [(None, 3)]          0           []
#
#  p_r33 (InputLayer)             [(None, 3)]          0           []
#
#  p_r34 (InputLayer)             [(None, 3)]          0           []
#
#  p_shared1 (Dense)              (None, 30)           120         ['p_r0[0][0]',
#                                                                   'p_r1[0][0]',
#                                                                   'p_r2[0][0]',
#                                                                   'p_r3[0][0]',
#                                                                   'p_r4[0][0]',
#                                                                   'p_r5[0][0]',
#                                                                   'p_r6[0][0]',
#                                                                   'p_r7[0][0]',
#                                                                   'p_r8[0][0]',
#                                                                   'p_r9[0][0]',
#                                                                   'p_r10[0][0]',
#                                                                   'p_r11[0][0]',
#                                                                   'p_r12[0][0]',
#                                                                   'p_r13[0][0]',
#                                                                   'p_r14[0][0]',
#                                                                   'p_r15[0][0]',
#                                                                   'p_r16[0][0]',
#                                                                   'p_r17[0][0]',
#                                                                   'p_r18[0][0]',
#                                                                   'p_r19[0][0]',
#                                                                   'p_r20[0][0]',
#                                                                   'p_r21[0][0]',
#                                                                   'p_r22[0][0]',
#                                                                   'p_r23[0][0]',
#                                                                   'p_r24[0][0]',
#                                                                   'p_r25[0][0]',
#                                                                   'p_r26[0][0]',
#                                                                   'p_r27[0][0]',
#                                                                   'p_r28[0][0]',
#                                                                   'p_r29[0][0]',
#                                                                   'p_r30[0][0]',
#                                                                   'p_r31[0][0]',
#                                                                   'p_r32[0][0]',
#                                                                   'p_r33[0][0]',
#                                                                   'p_r34[0][0]']
#
#  V_layer1 (Dense)               (None, 30)           120         ['V_in[0][0]']
#
#  p_shared2 (Dense)              (None, 30)           930         ['p_shared1[0][0]',
#                                                                   'p_shared1[1][0]',
#                                                                   'p_shared1[2][0]',
#                                                                   'p_shared1[3][0]',
#                                                                   'p_shared1[4][0]',
#                                                                   'p_shared1[5][0]',
#                                                                   'p_shared1[6][0]',
#                                                                   'p_shared1[7][0]',
#                                                                   'p_shared1[8][0]',
#                                                                   'p_shared1[9][0]',
#                                                                   'p_shared1[10][0]',
#                                                                   'p_shared1[11][0]',
#                                                                   'p_shared1[12][0]',
#                                                                   'p_shared1[13][0]',
#                                                                   'p_shared1[14][0]',
#                                                                   'p_shared1[15][0]',
#                                                                   'p_shared1[16][0]',
#                                                                   'p_shared1[17][0]',
#                                                                   'p_shared1[18][0]',
#                                                                   'p_shared1[19][0]',
#                                                                   'p_shared1[20][0]',
#                                                                   'p_shared1[21][0]',
#                                                                   'p_shared1[22][0]',
#                                                                   'p_shared1[23][0]',
#                                                                   'p_shared1[24][0]',
#                                                                   'p_shared1[25][0]',
#                                                                   'p_shared1[26][0]',
#                                                                   'p_shared1[27][0]',
#                                                                   'p_shared1[28][0]',
#                                                                   'p_shared1[29][0]',
#                                                                   'p_shared1[30][0]',
#                                                                   'p_shared1[31][0]',
#                                                                   'p_shared1[32][0]',
#                                                                   'p_shared1[33][0]',
#                                                                   'p_shared1[34][0]']
#
#  V_layer2 (Dense)               (None, 30)           930         ['V_layer1[0][0]']
#
#  p_shared3 (Dense)              (None, 30)           930         ['p_shared2[0][0]',
#                                                                   'p_shared2[1][0]',
#                                                                   'p_shared2[2][0]',
#                                                                   'p_shared2[3][0]',
#                                                                   'p_shared2[4][0]',
#                                                                   'p_shared2[5][0]',
#                                                                   'p_shared2[6][0]',
#                                                                   'p_shared2[7][0]',
#                                                                   'p_shared2[8][0]',
#                                                                   'p_shared2[9][0]',
#                                                                   'p_shared2[10][0]',
#                                                                   'p_shared2[11][0]',
#                                                                   'p_shared2[12][0]',
#                                                                   'p_shared2[13][0]',
#                                                                   'p_shared2[14][0]',
#                                                                   'p_shared2[15][0]',
#                                                                   'p_shared2[16][0]',
#                                                                   'p_shared2[17][0]',
#                                                                   'p_shared2[18][0]',
#                                                                   'p_shared2[19][0]',
#                                                                   'p_shared2[20][0]',
#                                                                   'p_shared2[21][0]',
#                                                                   'p_shared2[22][0]',
#                                                                   'p_shared2[23][0]',
#                                                                   'p_shared2[24][0]',
#                                                                   'p_shared2[25][0]',
#                                                                   'p_shared2[26][0]',
#                                                                   'p_shared2[27][0]',
#                                                                   'p_shared2[28][0]',
#                                                                   'p_shared2[29][0]',
#                                                                   'p_shared2[30][0]',
#                                                                   'p_shared2[31][0]',
#                                                                   'p_shared2[32][0]',
#                                                                   'p_shared2[33][0]',
#                                                                   'p_shared2[34][0]']
#
#  V_layer3 (Dense)               (None, 30)           930         ['V_layer2[0][0]']
#
#  multiply (Multiply)            (None, 30)           0           ['p_shared3[0][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_1 (Multiply)          (None, 30)           0           ['p_shared3[1][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_2 (Multiply)          (None, 30)           0           ['p_shared3[2][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_3 (Multiply)          (None, 30)           0           ['p_shared3[3][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_4 (Multiply)          (None, 30)           0           ['p_shared3[4][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_5 (Multiply)          (None, 30)           0           ['p_shared3[5][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_6 (Multiply)          (None, 30)           0           ['p_shared3[6][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_7 (Multiply)          (None, 30)           0           ['p_shared3[7][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_8 (Multiply)          (None, 30)           0           ['p_shared3[8][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_9 (Multiply)          (None, 30)           0           ['p_shared3[9][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_10 (Multiply)         (None, 30)           0           ['p_shared3[10][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_11 (Multiply)         (None, 30)           0           ['p_shared3[11][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_12 (Multiply)         (None, 30)           0           ['p_shared3[12][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_13 (Multiply)         (None, 30)           0           ['p_shared3[13][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_14 (Multiply)         (None, 30)           0           ['p_shared3[14][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_15 (Multiply)         (None, 30)           0           ['p_shared3[15][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_16 (Multiply)         (None, 30)           0           ['p_shared3[16][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_17 (Multiply)         (None, 30)           0           ['p_shared3[17][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_18 (Multiply)         (None, 30)           0           ['p_shared3[18][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_19 (Multiply)         (None, 30)           0           ['p_shared3[19][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_20 (Multiply)         (None, 30)           0           ['p_shared3[20][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_21 (Multiply)         (None, 30)           0           ['p_shared3[21][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_22 (Multiply)         (None, 30)           0           ['p_shared3[22][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_23 (Multiply)         (None, 30)           0           ['p_shared3[23][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_24 (Multiply)         (None, 30)           0           ['p_shared3[24][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_25 (Multiply)         (None, 30)           0           ['p_shared3[25][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_26 (Multiply)         (None, 30)           0           ['p_shared3[26][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_27 (Multiply)         (None, 30)           0           ['p_shared3[27][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_28 (Multiply)         (None, 30)           0           ['p_shared3[28][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_29 (Multiply)         (None, 30)           0           ['p_shared3[29][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_30 (Multiply)         (None, 30)           0           ['p_shared3[30][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_31 (Multiply)         (None, 30)           0           ['p_shared3[31][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_32 (Multiply)         (None, 30)           0           ['p_shared3[32][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_33 (Multiply)         (None, 30)           0           ['p_shared3[33][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_34 (Multiply)         (None, 30)           0           ['p_shared3[34][0]',
#                                                                   'V_layer3[0][0]']
#
#  proj_y0 (Lambda)               (None, 1)            0           ['p_r0[0][0]',
#                                                                   'multiply[0][0]']
#
#  proj_y1 (Lambda)               (None, 1)            0           ['p_r1[0][0]',
#                                                                   'multiply_1[0][0]']
#
#  proj_y2 (Lambda)               (None, 1)            0           ['p_r2[0][0]',
#                                                                   'multiply_2[0][0]']
#
#  proj_y3 (Lambda)               (None, 1)            0           ['p_r3[0][0]',
#                                                                   'multiply_3[0][0]']
#
#  proj_y4 (Lambda)               (None, 1)            0           ['p_r4[0][0]',
#                                                                   'multiply_4[0][0]']
#
#  proj_y5 (Lambda)               (None, 1)            0           ['p_r5[0][0]',
#                                                                   'multiply_5[0][0]']
#
#  proj_y6 (Lambda)               (None, 1)            0           ['p_r6[0][0]',
#                                                                   'multiply_6[0][0]']
#
#  proj_y7 (Lambda)               (None, 1)            0           ['p_r7[0][0]',
#                                                                   'multiply_7[0][0]']
#
#  proj_y8 (Lambda)               (None, 1)            0           ['p_r8[0][0]',
#                                                                   'multiply_8[0][0]']
#
#  proj_y9 (Lambda)               (None, 1)            0           ['p_r9[0][0]',
#                                                                   'multiply_9[0][0]']
#
#  proj_y10 (Lambda)              (None, 1)            0           ['p_r10[0][0]',
#                                                                   'multiply_10[0][0]']
#
#  proj_y11 (Lambda)              (None, 1)            0           ['p_r11[0][0]',
#                                                                   'multiply_11[0][0]']
#
#  proj_y12 (Lambda)              (None, 1)            0           ['p_r12[0][0]',
#                                                                   'multiply_12[0][0]']
#
#  proj_y13 (Lambda)              (None, 1)            0           ['p_r13[0][0]',
#                                                                   'multiply_13[0][0]']
#
#  proj_y14 (Lambda)              (None, 1)            0           ['p_r14[0][0]',
#                                                                   'multiply_14[0][0]']
#
#  proj_y15 (Lambda)              (None, 1)            0           ['p_r15[0][0]',
#                                                                   'multiply_15[0][0]']
#
#  proj_y16 (Lambda)              (None, 1)            0           ['p_r16[0][0]',
#                                                                   'multiply_16[0][0]']
#
#  proj_y17 (Lambda)              (None, 1)            0           ['p_r17[0][0]',
#                                                                   'multiply_17[0][0]']
#
#  proj_y18 (Lambda)              (None, 1)            0           ['p_r18[0][0]',
#                                                                   'multiply_18[0][0]']
#
#  proj_y19 (Lambda)              (None, 1)            0           ['p_r19[0][0]',
#                                                                   'multiply_19[0][0]']
#
#  proj_y20 (Lambda)              (None, 1)            0           ['p_r20[0][0]',
#                                                                   'multiply_20[0][0]']
#
#  proj_y21 (Lambda)              (None, 1)            0           ['p_r21[0][0]',
#                                                                   'multiply_21[0][0]']
#
#  proj_y22 (Lambda)              (None, 1)            0           ['p_r22[0][0]',
#                                                                   'multiply_22[0][0]']
#
#  proj_y23 (Lambda)              (None, 1)            0           ['p_r23[0][0]',
#                                                                   'multiply_23[0][0]']
#
#  proj_y24 (Lambda)              (None, 1)            0           ['p_r24[0][0]',
#                                                                   'multiply_24[0][0]']
#
#  proj_y25 (Lambda)              (None, 1)            0           ['p_r25[0][0]',
#                                                                   'multiply_25[0][0]']
#
#  proj_y26 (Lambda)              (None, 1)            0           ['p_r26[0][0]',
#                                                                   'multiply_26[0][0]']
#
#  proj_y27 (Lambda)              (None, 1)            0           ['p_r27[0][0]',
#                                                                   'multiply_27[0][0]']
#
#  proj_y28 (Lambda)              (None, 1)            0           ['p_r28[0][0]',
#                                                                   'multiply_28[0][0]']
#
#  proj_y29 (Lambda)              (None, 1)            0           ['p_r29[0][0]',
#                                                                   'multiply_29[0][0]']
#
#  proj_y30 (Lambda)              (None, 1)            0           ['p_r30[0][0]',
#                                                                   'multiply_30[0][0]']
#
#  proj_y31 (Lambda)              (None, 1)            0           ['p_r31[0][0]',
#                                                                   'multiply_31[0][0]']
#
#  proj_y32 (Lambda)              (None, 1)            0           ['p_r32[0][0]',
#                                                                   'multiply_32[0][0]']
#
#  proj_y33 (Lambda)              (None, 1)            0           ['p_r33[0][0]',
#                                                                   'multiply_33[0][0]']
#
#  proj_y34 (Lambda)              (None, 1)            0           ['p_r34[0][0]',
#                                                                   'multiply_34[0][0]']
#
#  proj_z0 (Lambda)               (None, 1)            0           ['p_r0[0][0]',
#                                                                   'multiply[0][0]']
#
#  proj_z1 (Lambda)               (None, 1)            0           ['p_r1[0][0]',
#                                                                   'multiply_1[0][0]']
#
#  proj_z2 (Lambda)               (None, 1)            0           ['p_r2[0][0]',
#                                                                   'multiply_2[0][0]']
#
#  proj_z3 (Lambda)               (None, 1)            0           ['p_r3[0][0]',
#                                                                   'multiply_3[0][0]']
#
#  proj_z4 (Lambda)               (None, 1)            0           ['p_r4[0][0]',
#                                                                   'multiply_4[0][0]']
#
#  proj_z5 (Lambda)               (None, 1)            0           ['p_r5[0][0]',
#                                                                   'multiply_5[0][0]']
#
#  proj_z6 (Lambda)               (None, 1)            0           ['p_r6[0][0]',
#                                                                   'multiply_6[0][0]']
#
#  proj_z7 (Lambda)               (None, 1)            0           ['p_r7[0][0]',
#                                                                   'multiply_7[0][0]']
#
#  proj_z8 (Lambda)               (None, 1)            0           ['p_r8[0][0]',
#                                                                   'multiply_8[0][0]']
#
#  proj_z9 (Lambda)               (None, 1)            0           ['p_r9[0][0]',
#                                                                   'multiply_9[0][0]']
#
#  proj_z10 (Lambda)              (None, 1)            0           ['p_r10[0][0]',
#                                                                   'multiply_10[0][0]']
#
#  proj_z11 (Lambda)              (None, 1)            0           ['p_r11[0][0]',
#                                                                   'multiply_11[0][0]']
#
#  proj_z12 (Lambda)              (None, 1)            0           ['p_r12[0][0]',
#                                                                   'multiply_12[0][0]']
#
#  proj_z13 (Lambda)              (None, 1)            0           ['p_r13[0][0]',
#                                                                   'multiply_13[0][0]']
#
#  proj_z14 (Lambda)              (None, 1)            0           ['p_r14[0][0]',
#                                                                   'multiply_14[0][0]']
#
#  proj_z15 (Lambda)              (None, 1)            0           ['p_r15[0][0]',
#                                                                   'multiply_15[0][0]']
#
#  proj_z16 (Lambda)              (None, 1)            0           ['p_r16[0][0]',
#                                                                   'multiply_16[0][0]']
#
#  proj_z17 (Lambda)              (None, 1)            0           ['p_r17[0][0]',
#                                                                   'multiply_17[0][0]']
#
#  proj_z18 (Lambda)              (None, 1)            0           ['p_r18[0][0]',
#                                                                   'multiply_18[0][0]']
#
#  proj_z19 (Lambda)              (None, 1)            0           ['p_r19[0][0]',
#                                                                   'multiply_19[0][0]']
#
#  proj_z20 (Lambda)              (None, 1)            0           ['p_r20[0][0]',
#                                                                   'multiply_20[0][0]']
#
#  proj_z21 (Lambda)              (None, 1)            0           ['p_r21[0][0]',
#                                                                   'multiply_21[0][0]']
#
#  proj_z22 (Lambda)              (None, 1)            0           ['p_r22[0][0]',
#                                                                   'multiply_22[0][0]']
#
#  proj_z23 (Lambda)              (None, 1)            0           ['p_r23[0][0]',
#                                                                   'multiply_23[0][0]']
#
#  proj_z24 (Lambda)              (None, 1)            0           ['p_r24[0][0]',
#                                                                   'multiply_24[0][0]']
#
#  proj_z25 (Lambda)              (None, 1)            0           ['p_r25[0][0]',
#                                                                   'multiply_25[0][0]']
#
#  proj_z26 (Lambda)              (None, 1)            0           ['p_r26[0][0]',
#                                                                   'multiply_26[0][0]']
#
#  proj_z27 (Lambda)              (None, 1)            0           ['p_r27[0][0]',
#                                                                   'multiply_27[0][0]']
#
#  proj_z28 (Lambda)              (None, 1)            0           ['p_r28[0][0]',
#                                                                   'multiply_28[0][0]']
#
#  proj_z29 (Lambda)              (None, 1)            0           ['p_r29[0][0]',
#                                                                   'multiply_29[0][0]']
#
#  proj_z30 (Lambda)              (None, 1)            0           ['p_r30[0][0]',
#                                                                   'multiply_30[0][0]']
#
#  proj_z31 (Lambda)              (None, 1)            0           ['p_r31[0][0]',
#                                                                   'multiply_31[0][0]']
#
#  proj_z32 (Lambda)              (None, 1)            0           ['p_r32[0][0]',
#                                                                   'multiply_32[0][0]']
#
#  proj_z33 (Lambda)              (None, 1)            0           ['p_r33[0][0]',
#                                                                   'multiply_33[0][0]']
#
#  proj_z34 (Lambda)              (None, 1)            0           ['p_r34[0][0]',
#                                                                   'multiply_34[0][0]']
#
#  concatenate (Concatenate)      (None, 35)           0           ['proj_y0[0][0]',
#                                                                   'proj_y1[0][0]',
#                                                                   'proj_y2[0][0]',
#                                                                   'proj_y3[0][0]',
#                                                                   'proj_y4[0][0]',
#                                                                   'proj_y5[0][0]',
#                                                                   'proj_y6[0][0]',
#                                                                   'proj_y7[0][0]',
#                                                                   'proj_y8[0][0]',
#                                                                   'proj_y9[0][0]',
#                                                                   'proj_y10[0][0]',
#                                                                   'proj_y11[0][0]',
#                                                                   'proj_y12[0][0]',
#                                                                   'proj_y13[0][0]',
#                                                                   'proj_y14[0][0]',
#                                                                   'proj_y15[0][0]',
#                                                                   'proj_y16[0][0]',
#                                                                   'proj_y17[0][0]',
#                                                                   'proj_y18[0][0]',
#                                                                   'proj_y19[0][0]',
#                                                                   'proj_y20[0][0]',
#                                                                   'proj_y21[0][0]',
#                                                                   'proj_y22[0][0]',
#                                                                   'proj_y23[0][0]',
#                                                                   'proj_y24[0][0]',
#                                                                   'proj_y25[0][0]',
#                                                                   'proj_y26[0][0]',
#                                                                   'proj_y27[0][0]',
#                                                                   'proj_y28[0][0]',
#                                                                   'proj_y29[0][0]',
#                                                                   'proj_y30[0][0]',
#                                                                   'proj_y31[0][0]',
#                                                                   'proj_y32[0][0]',
#                                                                   'proj_y33[0][0]',
#                                                                   'proj_y34[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 35)           0           ['proj_z0[0][0]',
#                                                                   'proj_z1[0][0]',
#                                                                   'proj_z2[0][0]',
#                                                                   'proj_z3[0][0]',
#                                                                   'proj_z4[0][0]',
#                                                                   'proj_z5[0][0]',
#                                                                   'proj_z6[0][0]',
#                                                                   'proj_z7[0][0]',
#                                                                   'proj_z8[0][0]',
#                                                                   'proj_z9[0][0]',
#                                                                   'proj_z10[0][0]',
#                                                                   'proj_z11[0][0]',
#                                                                   'proj_z12[0][0]',
#                                                                   'proj_z13[0][0]',
#                                                                   'proj_z14[0][0]',
#                                                                   'proj_z15[0][0]',
#                                                                   'proj_z16[0][0]',
#                                                                   'proj_z17[0][0]',
#                                                                   'proj_z18[0][0]',
#                                                                   'proj_z19[0][0]',
#                                                                   'proj_z20[0][0]',
#                                                                   'proj_z21[0][0]',
#                                                                   'proj_z22[0][0]',
#                                                                   'proj_z23[0][0]',
#                                                                   'proj_z24[0][0]',
#                                                                   'proj_z25[0][0]',
#                                                                   'proj_z26[0][0]',
#                                                                   'proj_z27[0][0]',
#                                                                   'proj_z28[0][0]',
#                                                                   'proj_z29[0][0]',
#                                                                   'proj_z30[0][0]',
#                                                                   'proj_z31[0][0]',
#                                                                   'proj_z32[0][0]',
#                                                                   'proj_z33[0][0]',
#                                                                   'proj_z34[0][0]']
#
#  out_y (Dense)                  (None, 1)            35          ['concatenate[0][0]']
#
#  out_z (Dense)                  (None, 1)            35          ['concatenate_1[0][0]']
#
#  out_concat_layer (Concatenate)  (None, 2)           0           ['out_y[0][0]',
#                                                                   'out_z[0][0]']
#
# ==================================================================================================
# Total params: 4,030
# Trainable params: 4,030
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2033

# %% [markdown]
# ## $T_L$

# %%
# %reset -f array
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# free up memory from previous plots_________________
plt.close('all')
plt.clf()

coord = r'T_L' 

# load dataset _______________________________________
Re = 150
phi = 4

num_p_incl = 6
N_neurons = 10
epochs = 500
lr = 8e-3
verbose = 0
batch_size = 128

# coord, title = 'F_x', r'$ Re = ' + f'{Re},' + r' \phi = ' + f'{phi} $'

os.chdir("/home/zihao/Documents/PhD/Post-Processing/3D/Bidisperse")
dataset = pd.read_csv(f'Arman_PINN/raw/new_Re{Re}_phi0{phi}',
                        header=None, delim_whitespace=True).values

col_n = -3

X_in = dataset[:, :-6]
if coord == 'F_L':
    Y_in = dataset[:, -2:]
if coord == 'T_L':
    Y_in = dataset[:, -5:-3]
Y_in -= Y_in.mean(axis=0)

HUBER_ALPHA = max(Y_in[:,0].std(),Y_in[:,1].std())
print(HUBER_ALPHA)
    
kf = KFold(n_splits=5, shuffle=True)
train_scores = []
test_scores = []

X_test_plot = np.zeros((0, X_in.shape[1]))
Y_test_plot = np.zeros((0, Y_in.shape[1]))
Y_pred_test_plot = np.zeros((0, Y_in.shape[1]))

# from IPython.display import display, Math
# display(Math('$ \Delta ' + coord + ' $'))
# display(Math(title))

print('Input shape:', X_in.shape)
print(f'# of neighbors in the dataset = {int((X_in.shape[1] - 3) / 3)}')
print(f'# of neighbors used for training = {num_p_incl}')
print('________________________________________')

q = 0
Total_time_train = 0
Total_time_test  = 0
# Train-Test split for K-fold cross-validation _______________________________________
for train_index, test_index in kf.split(X_in):
    
    q += 1
    print(f'+++++++++++++++++++++++++Fold {q:1d}+++++++++++++++++++++++++')

    X_train_list = []
    X_test_list = []
    p_input_list = []
    p_out_list = []
    
    X_train, X_test = X_in[train_index], X_in[test_index]
    Y_train, Y_test = Y_in[train_index], Y_in[test_index]
            
    V_in_train = X_train[:, col_n:]
    V_in_test  = X_test[:, col_n:]
    
    # X_train_tmp = X_train
    # for p in range(0, 30):
    #     X_train_tmp[:,3*p+1] = -X_train_tmp[:,3*p+1]
    # X_train = np.vstack((X_train,X_train_tmp))
    # X_train_tmp = X_train
    # for p in range(0, 30):
    #     X_train_tmp[:,3*p+2] = -X_train_tmp[:,3*p+2]
    # X_train = np.vstack((X_train,X_train_tmp))
    # Y_train = np.vstack((Y_train,Y_train))
    # Y_train = np.vstack((Y_train,Y_train))
    # V_in_train_tmp = V_in_train
    # V_in_train_tmp[:,-2] = -V_in_train_tmp[:,-2]
    # V_in_train = np.vstack((V_in_train,V_in_train_tmp))
    # V_in_train_tmp = V_in_train
    # V_in_train_tmp[:,-1] = -V_in_train_tmp[:,-1]
    # V_in_train = np.vstack((V_in_train,V_in_train_tmp))
    
    # Training =======================================
    glorot = tf.keras.initializers.GlorotNormal()
        
    # Custom neural network _______________________________________
    p_shared_layer1 = Dense(N_neurons,
                            activation='elu',
                            kernel_initializer=glorot,
                            name='p_shared1')
    
    p_shared_layer2 = Dense(N_neurons,
                            activation='elu',
                            kernel_initializer=glorot,
                            name='p_shared2')
    
    p_shared_layer3 = Dense(N_neurons,
                            activation='elu',
                            kernel_initializer=glorot,
                            name='p_shared3')
    
    # p_shared_layer4 = Dense(N_neurons,
    #                         activation='elu',
    #                         kernel_initializer=glorot,
    #                         name='p_shared4')
    
#     p_shared_layer5 = Dense(N_neurons,
#                             activation='tanh',
#                             kernel_initializer=glorot,
#                             name='p_shared5')
    
    V_input = Input(shape=V_in_train.shape[1], name='V_in')
    
    V_layer = Dense(N_neurons,
                     activation='elu',
                     kernel_initializer=glorot,
                     name='V_layer1')(V_input)
    
    V_layer = Dense(N_neurons,
                     activation='elu',
                     kernel_initializer=glorot,
                     name='V_layer2')(V_layer)
    
    V_layer = Dense(N_neurons,
                     activation='elu',
                     kernel_initializer=glorot,
                     name='V_layer3')(V_layer)
    
    # V_layer = Dense(N_neurons,
    #                  activation='elu',
    #                  kernel_initializer=glorot,
    #                  name='V_layer4')(V_layer)
    
#     V_layer = Dense(N_neurons,
#                      activation='relu',
#                      kernel_initializer=glorot,
#                      name='V_layer5')(V_layer)
    
    def project_y(inputs):
        pos_vec = inputs[0]
        p_tensor = inputs[1]

        e_x = tf.constant(np.array([1, 0, 0]), shape=(1, 3), dtype=tf.float32)
        e_y = tf.constant(np.array([0, 1, 0]), shape=(1, 3), dtype=tf.float32)
        e_z = tf.constant(np.array([0, 0, 1]), shape=(1, 3), dtype=tf.float32)

        e_x = tf.broadcast_to(e_x, shape=(tf.shape(p_tensor)[0], 3))
        e_y = tf.broadcast_to(e_y, shape=(tf.shape(p_tensor)[0], 3))
        e_z = tf.broadcast_to(e_z, shape=(tf.shape(p_tensor)[0], 3))

        e_r = pos_vec / tf.linalg.norm(pos_vec, axis=1, keepdims=True)

        # Lift _______________________________________
        if coord == 'F_L':
            e_ctrb = tf.linalg.cross(tf.linalg.cross(e_x, e_r), e_x)

        # Torque _______________________________________
        if coord == 'T_L':
            e_ctrb = tf.linalg.cross(e_x, e_r)

        e_ctrb /= tf.linalg.norm(e_ctrb, axis=1, keepdims=True)
        ctrb = tf.reduce_sum(p_tensor, axis=1, keepdims=True) * e_ctrb

        return tf.reduce_sum( tf.multiply( ctrb, e_y ), axis=1, keepdims=True )
    #_______________________________________________________________________________

    def project_z(inputs):
        pos_vec = inputs[0]
        p_tensor = inputs[1]

        e_x = tf.constant(np.array([1, 0, 0]), shape=(1, 3), dtype=tf.float32)
        e_y = tf.constant(np.array([0, 1, 0]), shape=(1, 3), dtype=tf.float32)
        e_z = tf.constant(np.array([0, 0, 1]), shape=(1, 3), dtype=tf.float32)

        e_x = tf.broadcast_to(e_x, shape=(tf.shape(p_tensor)[0], 3))
        e_y = tf.broadcast_to(e_y, shape=(tf.shape(p_tensor)[0], 3))
        e_z = tf.broadcast_to(e_z, shape=(tf.shape(p_tensor)[0], 3))
        
        e_r = pos_vec / tf.linalg.norm(pos_vec, axis=1, keepdims=True)

        # Lift _______________________________________
        if coord == 'F_L':
            e_ctrb = tf.linalg.cross(tf.linalg.cross(e_x, e_r), e_x)

        # Torque _______________________________________
        if coord == 'T_L':
            e_ctrb = tf.linalg.cross(e_x, e_r)

        e_ctrb /= tf.linalg.norm(e_ctrb, axis=1, keepdims=True)
        ctrb = tf.reduce_sum(p_tensor, axis=1, keepdims=True) * e_ctrb

        return tf.reduce_sum( tf.multiply( ctrb, e_z ), axis=1, keepdims=True )
    #_______________________________________________________________________________

    for p in range(0, num_p_incl):
        X_train_list.append( X_train[:, 3*p:3*p+3])
        p_input_list.append( Input(shape=3, name=f'p_r{p}') )
        # p_out_list.append( tf.keras.layers.Multiply()([tf.keras.layers.Multiply()
        #                   ([p_shared_layer2(p_shared_layer1(p_input_list[p])),V_layer])
        #                                                ,R_input]) )
        # p_out_list.append( tf.keras.layers.Multiply()([p_shared_layer2(p_shared_layer1(p_input_list[p]))
        #                                                ,V_layer]) )
        p_out_list.append( tf.keras.layers.Multiply()([p_shared_layer3(p_shared_layer2(p_shared_layer1(p_input_list[p])))
                                                       ,V_layer]) )
        # p_out_list.append( tf.keras.layers.Multiply()([p_shared_layer4(p_shared_layer3(p_shared_layer2(p_shared_layer1(p_input_list[p]))))
        #                                                ,V_layer]) )

    ctrb_y = Concatenate()(
        [Lambda(project_y, name=f'proj_y{j}')([p_input_list[j], p_out_list[j]])\
        for j in range(num_p_incl)])
    ctrb_z = Concatenate()(
        [Lambda(project_z, name=f'proj_z{j}')([p_input_list[j], p_out_list[j]])\
        for j in range(num_p_incl)])

    nonneg = tf.keras.constraints.NonNeg()

    out_y = Dense(1, activation='linear',
                #   kernel_initializer=tf.keras.initializers.zeros(),
                  kernel_constraint=nonneg,
                name='out_y', use_bias=False)(ctrb_y)
    out_z = Dense(1, activation='linear',
                #   kernel_initializer=tf.keras.initializers.zeros(),
                  kernel_constraint=nonneg,
                name='out_z', use_bias=False)(ctrb_z)
    
    out = Concatenate(name='out_concat_layer')([out_y, out_z])
    
    # Neural net fitting _______________________________________
    
    def R2_val(y_true, y_pred):
        '''
        This function computes the R^2 for the callback function.
        '''
        SS_res = K.sum(K.square(y_true - y_pred)) 
        SS_tot = K.sum(K.square(y_true - K.mean(y_true,axis=0))) 
        return 1 - SS_res / (SS_tot + K.epsilon())
    
    model = Model(inputs=p_input_list + [V_input], outputs=out)

    myoptimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    # myoptimizer = tf.keras.optimizers.Nadam(learning_rate=lr)
    EarlyStop = EarlyStopping(monitor='val_loss', patience=60, min_delta=1e-5)
    LRDecay = ReduceLROnPlateau(monitor='val_loss', patience=20, factor=0.5, min_delta=5e-5)

    # model.compile(loss='mse', optimizer=myoptimizer, metrics=[metrics.mean_squared_error])
    # model.compile(loss='mean_absolute_error', optimizer=myoptimizer, metrics=[metrics.mean_squared_error])
    he = tf.keras.losses.Huber(delta=HUBER_ALPHA)
    model.compile(loss=he, optimizer=myoptimizer, metrics=R2_val)
    
    history_drag = model.fit(
                            X_train_list + [V_in_train],
                            Y_train,

                            validation_split=0.2,
                            shuffle=True,
                            epochs=epochs,
                            verbose=verbose,
                            batch_size=batch_size,
                            callbacks=[LRDecay,EarlyStop],
                            )
    
    start_time = time.perf_counter()
    Y_pred = model.predict(X_train_list + [V_in_train])
    end_time = time.perf_counter()
    print(f'CPU time: {end_time-start_time:.3f} for {Y_pred.shape[0]:8d} datapoints')
    Total_time_train += end_time-start_time
    
    print(f'Train R^2\t= {r2_score(Y_train, Y_pred):.3f}\n')
    train_scores.append(r2_score(Y_train, Y_pred))
    
    # Testing =======================================
    for p in range(0, num_p_incl):
        X_test_list.append( X_test[:, 3*p:3*p+3] )
        
    start_time = time.perf_counter()
    Y_pred_test = model.predict(X_test_list + [V_in_test])
    end_time = time.perf_counter()
    print(f'CPU time: {end_time-start_time:.3f} for {Y_pred_test.shape[0]:8d} datapoints')
    Total_time_test += end_time-start_time
    
    print(f'Test R^2\t= {r2_score(Y_test, Y_pred_test):.3f}\n')
    test_scores.append(r2_score(Y_test, Y_pred_test))

    # os.chdir("/home/zihao/Documents/PhD/Post-Processing/3D/Bidisperse/Datasets/Paper_3")
    # model.save(f'model_{coord}_Re{Re}_phi{phi}.h5')
    # os.chdir("../../")
    
    print(f'++++++++++++++++++++++++++++++++++++++++++++++++++++++++\n')
    
    if q != 5:
        del model
        K.clear_session()   
        gc.collect()
# os.chdir("/home/zihao/Documents/PhD/Post-Processing/3D/Bidisperse/Datasets/Paper_3")
# np.save(f'Re{Re}_phi{phi}_large_true_drag.npy',Y_large_test_plot)
# np.save(f'Re{Re}_phi{phi}_large_pred_drag.npy',Y_large_pred_test_plot)
# np.save(f'Re{Re}_phi{phi}_small_true_drag.npy',Y_small_test_plot)
# np.save(f'Re{Re}_phi{phi}_small_pred_drag.npy',Y_small_pred_test_plot)
# os.chdir("../../")

Average_train_scores = np.mean(train_scores)
Average_test_scores = np.mean(test_scores)

print('========================================\nOverall performance:')
print(f'<Average Train R^2> = {Average_train_scores:.3f}')
print(f'<Average Test R^2> = {Average_test_scores:.3f}')
print(f'<Average Train time> = {(Total_time_train/5):.3f}')
print(f'<Average Test time> = {(Total_time_test/5):.3f}')

print(f'\nTotal number of model parameters: {model.count_params()}\n')
# os.chdir("/home/zihao/Documents/PhD/Post-Processing/3D/Bidisperse/Datasets/Paper_3")
# model.save(f'model_{coord}_Re{Re}_phi{phi}.h5')
# os.chdir("../../")
model.summary()
del model
K.clear_session()   
gc.collect()
# Out:
# 4.093980262268184
# Input shape: (2578, 300)
# # of neighbors in the dataset = 99
# # of neighbors used for training = 6
# ________________________________________
# +++++++++++++++++++++++++Fold 1+++++++++++++++++++++++++
# 65/65 [==============================] - 1s 2ms/step
# CPU time: 0.627 for     2062 datapoints
# Train R^2	= 0.631
#
# 17/17 [==============================] - 0s 2ms/step
# CPU time: 0.180 for      516 datapoints
# Test R^2	= 0.632
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++Fold 2+++++++++++++++++++++++++
# 65/65 [==============================] - 1s 4ms/step
# CPU time: 0.721 for     2062 datapoints
# Train R^2	= 0.638
#
# 17/17 [==============================] - 0s 3ms/step
# CPU time: 0.208 for      516 datapoints
# Test R^2	= 0.619
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++Fold 3+++++++++++++++++++++++++
# 65/65 [==============================] - 0s 2ms/step
# CPU time: 0.495 for     2062 datapoints
# Train R^2	= 0.636
#
# 17/17 [==============================] - 0s 2ms/step
# CPU time: 0.183 for      516 datapoints
# Test R^2	= 0.612
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++Fold 4+++++++++++++++++++++++++
# 65/65 [==============================] - 0s 2ms/step
# CPU time: 0.506 for     2063 datapoints
# Train R^2	= 0.638
#
# 17/17 [==============================] - 0s 4ms/step
# CPU time: 0.272 for      515 datapoints
# Test R^2	= 0.621
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# +++++++++++++++++++++++++Fold 5+++++++++++++++++++++++++
# 65/65 [==============================] - 0s 2ms/step
# CPU time: 0.439 for     2063 datapoints
# Train R^2	= 0.641
#
# 17/17 [==============================] - 0s 2ms/step
# CPU time: 0.279 for      515 datapoints
# Test R^2	= 0.607
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# ========================================
# Overall performance:
# <Average Train R^2> = 0.637
# <Average Test R^2> = 0.618
# <Average Train time> = 0.558
# <Average Test time> = 0.225
#
# Total number of model parameters: 532
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  p_r0 (InputLayer)              [(None, 3)]          0           []
#
#  V_in (InputLayer)              [(None, 3)]          0           []
#
#  p_r1 (InputLayer)              [(None, 3)]          0           []
#
#  p_r2 (InputLayer)              [(None, 3)]          0           []
#
#  p_r3 (InputLayer)              [(None, 3)]          0           []
#
#  p_r4 (InputLayer)              [(None, 3)]          0           []
#
#  p_r5 (InputLayer)              [(None, 3)]          0           []
#
#  p_shared1 (Dense)              (None, 10)           40          ['p_r0[0][0]',
#                                                                   'p_r1[0][0]',
#                                                                   'p_r2[0][0]',
#                                                                   'p_r3[0][0]',
#                                                                   'p_r4[0][0]',
#                                                                   'p_r5[0][0]']
#
#  V_layer1 (Dense)               (None, 10)           40          ['V_in[0][0]']
#
#  p_shared2 (Dense)              (None, 10)           110         ['p_shared1[0][0]',
#                                                                   'p_shared1[1][0]',
#                                                                   'p_shared1[2][0]',
#                                                                   'p_shared1[3][0]',
#                                                                   'p_shared1[4][0]',
#                                                                   'p_shared1[5][0]']
#
#  V_layer2 (Dense)               (None, 10)           110         ['V_layer1[0][0]']
#
#  p_shared3 (Dense)              (None, 10)           110         ['p_shared2[0][0]',
#                                                                   'p_shared2[1][0]',
#                                                                   'p_shared2[2][0]',
#                                                                   'p_shared2[3][0]',
#                                                                   'p_shared2[4][0]',
#                                                                   'p_shared2[5][0]']
#
#  V_layer3 (Dense)               (None, 10)           110         ['V_layer2[0][0]']
#
#  multiply (Multiply)            (None, 10)           0           ['p_shared3[0][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_1 (Multiply)          (None, 10)           0           ['p_shared3[1][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_2 (Multiply)          (None, 10)           0           ['p_shared3[2][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_3 (Multiply)          (None, 10)           0           ['p_shared3[3][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_4 (Multiply)          (None, 10)           0           ['p_shared3[4][0]',
#                                                                   'V_layer3[0][0]']
#
#  multiply_5 (Multiply)          (None, 10)           0           ['p_shared3[5][0]',
#                                                                   'V_layer3[0][0]']
#
#  proj_y0 (Lambda)               (None, 1)            0           ['p_r0[0][0]',
#                                                                   'multiply[0][0]']
#
#  proj_y1 (Lambda)               (None, 1)            0           ['p_r1[0][0]',
#                                                                   'multiply_1[0][0]']
#
#  proj_y2 (Lambda)               (None, 1)            0           ['p_r2[0][0]',
#                                                                   'multiply_2[0][0]']
#
#  proj_y3 (Lambda)               (None, 1)            0           ['p_r3[0][0]',
#                                                                   'multiply_3[0][0]']
#
#  proj_y4 (Lambda)               (None, 1)            0           ['p_r4[0][0]',
#                                                                   'multiply_4[0][0]']
#
#  proj_y5 (Lambda)               (None, 1)            0           ['p_r5[0][0]',
#                                                                   'multiply_5[0][0]']
#
#  proj_z0 (Lambda)               (None, 1)            0           ['p_r0[0][0]',
#                                                                   'multiply[0][0]']
#
#  proj_z1 (Lambda)               (None, 1)            0           ['p_r1[0][0]',
#                                                                   'multiply_1[0][0]']
#
#  proj_z2 (Lambda)               (None, 1)            0           ['p_r2[0][0]',
#                                                                   'multiply_2[0][0]']
#
#  proj_z3 (Lambda)               (None, 1)            0           ['p_r3[0][0]',
#                                                                   'multiply_3[0][0]']
#
#  proj_z4 (Lambda)               (None, 1)            0           ['p_r4[0][0]',
#                                                                   'multiply_4[0][0]']
#
#  proj_z5 (Lambda)               (None, 1)            0           ['p_r5[0][0]',
#                                                                   'multiply_5[0][0]']
#
#  concatenate (Concatenate)      (None, 6)            0           ['proj_y0[0][0]',
#                                                                   'proj_y1[0][0]',
#                                                                   'proj_y2[0][0]',
#                                                                   'proj_y3[0][0]',
#                                                                   'proj_y4[0][0]',
#                                                                   'proj_y5[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 6)            0           ['proj_z0[0][0]',
#                                                                   'proj_z1[0][0]',
#                                                                   'proj_z2[0][0]',
#                                                                   'proj_z3[0][0]',
#                                                                   'proj_z4[0][0]',
#                                                                   'proj_z5[0][0]']
#
#  out_y (Dense)                  (None, 1)            6           ['concatenate[0][0]']
#
#  out_z (Dense)                  (None, 1)            6           ['concatenate_1[0][0]']
#
#  out_concat_layer (Concatenate)  (None, 2)           0           ['out_y[0][0]',
#                                                                   'out_z[0][0]']
#
# ==================================================================================================
# Total params: 532
# Trainable params: 532
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 7633
